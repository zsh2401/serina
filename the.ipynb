# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib as mpl
import matplotlib.pyplot as plt  # data visualization
import seaborn as sns  # statistical data visualization

# %%
import torch.utils.data

torch.manual_seed(3407)

df = pd.read_csv("./ESC-50/meta/esc50.csv")


# df.head()
# 选择每个类别的前 60% 数据
def select(group, start_percent, end_percent):
    start = int(len(group) * start_percent)  # 计算 60% 的位置
    end = int(len(group) * end_percent)  # 计算 80% 的位置
    return group.iloc[start:end]


# df.groupby("category")
sampled_df = df.groupby('category').apply(lambda x: select(x,0,0.6))

# 重置索引
sampled_df = sampled_df.reset_index(drop=True)
# Out:
# 1200

# %%
categories = df["category"].nunique()
print(f"有{categories}种取值")
# Out:
# 有50种取值

# %% [markdown]
# 接下来，准备数据集

# %%
import torchaudio
from torchaudio.transforms import MelSpectrogram, AmplitudeToDB
from label import label_to_index
from torch.utils.data import Dataset, DataLoader


class SoundDataset(Dataset):
    def __init__(self):
        self.transformation = torchaudio.transforms.Spectrogram()
        self.target_sample_rate = 16_000

    def __len__(self):
        return len(df)

    def __getitem__(self, item):
        row = df.take([item], axis=0)

        file_path = "./ESC-50/audio/" + row.filename.values[0]
        waveform, sample_rate = torchaudio.load(file_path)
        if sample_rate != self.target_sample_rate:
            resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=self.target_sample_rate)
            waveform = resampler(waveform)

        waveform = self.transformation(waveform)
        # mel_spectrogram = MelSpectrogram(sample_rate)(waveform)
        # mel_spectrogram_db = AmplitudeToDB()(mel_spectrogram)

        return waveform, label_to_index(row.category.values[0])


dataset = SoundDataset()
dataloader = DataLoader(dataset, shuffle=True, batch_size=128)

# %% [markdown]
# 接下来编写模型

# %%
import torch.nn as nn
import torch.nn.functional as F


class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(160_000, 64)
        self.fc2 = nn.Linear(64, categories)  # 假设有10个类别

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


model = SimpleCNN()
model.to("mps")
# Out:
# SimpleCNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=160000, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=50, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss().to("mps")
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(10):  # 迭代多个周期
    for i, (inputs, labels) in enumerate(dataloader):
        labels = labels.to("mps")
        inputs = inputs.to("mps")
        # 梯度清零
        optimizer.zero_grad()

        # 前向 + 反向 + 优化
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        print(f'Epoch: {epoch + 1}, Batch: {i + 1}, Loss: {loss.item()}')
# Out:
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 1, Loss: 7.473263740539551
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 2, Loss: 56.15425491333008
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 3, Loss: 57.1718864440918
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 4, Loss: 19.05189323425293
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 5, Loss: 22.901779174804688
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 6, Loss: 29.38726806640625
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 7, Loss: 14.476642608642578
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 8, Loss: 11.876070976257324
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 9, Loss: 9.965805053710938
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 10, Loss: 6.164563179016113
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 11, Loss: 6.350220203399658
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 12, Loss: 6.858315467834473
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 13, Loss: 5.705517292022705
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 14, Loss: 6.0186357498168945
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 15, Loss: 3.8954639434814453
# 暴力训练中
# 什么都没有我操了
# Epoch: 1, Batch: 16, Loss: 5.233518600463867
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 1, Loss: 3.7302041053771973
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 2, Loss: 4.015892028808594
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 3, Loss: 3.662909507751465
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 4, Loss: 3.877410888671875
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 5, Loss: 3.6781070232391357
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 6, Loss: 3.6503233909606934
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 7, Loss: 3.7154204845428467
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 8, Loss: 3.705282211303711
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 9, Loss: 3.7136569023132324
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 10, Loss: 3.6298365592956543
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 11, Loss: 3.7294960021972656
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 12, Loss: 3.6247658729553223
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 13, Loss: 3.690056800842285
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 14, Loss: 3.6645874977111816
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 15, Loss: 3.810231924057007
# 暴力训练中
# 什么都没有我操了
# Epoch: 2, Batch: 16, Loss: 3.6651527881622314
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 1, Loss: 3.6033778190612793
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 2, Loss: 3.6740527153015137
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 3, Loss: 3.5338382720947266
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 4, Loss: 3.5436034202575684
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 5, Loss: 3.570500373840332
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 6, Loss: 3.6311652660369873
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 7, Loss: 3.652477741241455
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 8, Loss: 3.587336301803589
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 9, Loss: 3.60295033454895
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 10, Loss: 3.6396355628967285
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 11, Loss: 3.5598559379577637
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 12, Loss: 3.7323431968688965
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 13, Loss: 3.559968948364258
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 14, Loss: 3.367011785507202
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 15, Loss: 3.5917868614196777
# 暴力训练中
# 什么都没有我操了
# Epoch: 3, Batch: 16, Loss: 3.3753418922424316
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 1, Loss: 3.4261786937713623
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 2, Loss: 3.5964808464050293
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 3, Loss: 3.4525396823883057
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 4, Loss: 3.3275327682495117
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 5, Loss: 3.372070074081421
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 6, Loss: 3.3578968048095703
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 7, Loss: 3.345442771911621
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 8, Loss: 3.3829073905944824
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 9, Loss: 3.26932430267334
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 10, Loss: 3.331144094467163
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 11, Loss: 3.299760580062866
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 12, Loss: 3.3574867248535156
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 13, Loss: 3.246929168701172
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 14, Loss: 3.3993165493011475
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 15, Loss: 3.425469398498535
# 暴力训练中
# 什么都没有我操了
# Epoch: 4, Batch: 16, Loss: 3.3551363945007324
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 1, Loss: 3.2160804271698
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 2, Loss: 3.1819982528686523
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 3, Loss: 3.0972602367401123
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 4, Loss: 3.329782724380493
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 5, Loss: 2.896043062210083
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 6, Loss: 3.0993080139160156
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 7, Loss: 3.111567735671997
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 8, Loss: 3.0149197578430176
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 9, Loss: 3.0949745178222656
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 10, Loss: 3.090601682662964
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 11, Loss: 2.95943546295166
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 12, Loss: 2.925854444503784
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 13, Loss: 2.8667283058166504
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 14, Loss: 2.8590636253356934
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 15, Loss: 2.9734907150268555
# 暴力训练中
# 什么都没有我操了
# Epoch: 5, Batch: 16, Loss: 3.212240219116211
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 1, Loss: 2.6129326820373535
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 2, Loss: 2.7070789337158203
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 3, Loss: 2.953279972076416
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 4, Loss: 2.717287540435791
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 5, Loss: 2.708772659301758
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 6, Loss: 2.6461544036865234
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 7, Loss: 2.5339126586914062
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 8, Loss: 2.632575750350952
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 9, Loss: 2.5900754928588867
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 10, Loss: 2.5901718139648438
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 11, Loss: 2.6104466915130615
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 12, Loss: 2.5604374408721924
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 13, Loss: 2.470968723297119
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 14, Loss: 2.6386561393737793
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 15, Loss: 2.4834678173065186
# 暴力训练中
# 什么都没有我操了
# Epoch: 6, Batch: 16, Loss: 2.2976572513580322
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 1, Loss: 2.360030174255371
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 2, Loss: 2.1504464149475098
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 3, Loss: 2.0666251182556152
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 4, Loss: 2.022315740585327
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 5, Loss: 2.322763204574585
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 6, Loss: 1.848282814025879
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 7, Loss: 1.9445338249206543
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 8, Loss: 2.096695899963379
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 9, Loss: 2.0554771423339844
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 10, Loss: 2.0098419189453125
# 暴力训练中
# 什么都没有我操了
# Epoch: 7, Batch: 11, Loss: 2.2330193519592285
# 暴力训练中
# 什么都没有我操了
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 21
#      18 loss.backward()
#      19 optimizer.step()
# ---> 21 print(f'Epoch: {epoch + 1}, Batch: {i + 1}, Loss: {loss.item()}')
#
# KeyboardInterrupt:
